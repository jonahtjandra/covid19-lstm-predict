# %%
import pandas as pd

# %%
covidData = pd.read_csv("covid.csv")

# %%
#previewing the dataset
covidData.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
#numbers of rows and columns
covidData.shape
# Out:
# (72775, 59)

# %%
covidData.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
#looking at the different locations
covidData["location"].value_counts()
# Out:
# Argentina           429
# Mexico              429
# Thailand            426
# Taiwan              414
# South Korea         409
#                    ...
# Falkland Islands     16
# Montserrat           16
# Macao                11
# Northern Cyprus       9
# Saint Helena          1
# Name: location, Length: 215, dtype: int64

# %%
#description of the categorical columns of the dataset
covidData.describe(include = 'O')
# Out:
#        iso_code continent   location        date      tests_units
# count     72775     69168      72775       72775            38760
# unique      215         6        215         429                4
# top         ARG    Africa  Argentina  2021-02-08  tests performed
# freq        429     19112        429         212            23368

# %%
#checking for null values
covidData.isna().any()
# Out:
# iso_code                                 False
# continent                                 True
# location                                 False
# date                                     False
# total_cases                               True
# new_cases                                 True
# new_cases_smoothed                        True
# total_deaths                              True
# new_deaths                                True
# new_deaths_smoothed                       True
# total_cases_per_million                   True
# new_cases_per_million                     True
# new_cases_smoothed_per_million            True
# total_deaths_per_million                  True
# new_deaths_per_million                    True
# new_deaths_smoothed_per_million           True
# reproduction_rate                         True
# icu_patients                              True
# icu_patients_per_million                  True
# hosp_patients                             True
# ...

# %%
#sum of null values
covidData.isna().sum()
# Out:
# iso_code                                     0
# continent                                 3607
# location                                     0
# date                                         0
# total_cases                               1046
# new_cases                                 1048
# new_cases_smoothed                        2049
# total_deaths                             10169
# new_deaths                               10011
# new_deaths_smoothed                       2049
# total_cases_per_million                   1438
# new_cases_per_million                     1440
# new_cases_smoothed_per_million            2436
# total_deaths_per_million                 10548
# new_deaths_per_million                   10390
# new_deaths_smoothed_per_million           2436
# reproduction_rate                        14408
# icu_patients                             65136
# icu_patients_per_million                 65136
# hosp_patients                            63590
# ...

# %%
#Getting the specific data in a specific country
indonesia_case = covidData[covidData["location"] == "Indonesia"]
usa_case = covidData[covidData["location"] == "United States"]

# %%
indonesia_case.head()
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 30304      IDN      Asia  Indonesia  2020-03-02          2.0        2.0
# 30305      IDN      Asia  Indonesia  2020-03-03          2.0        0.0
# 30306      IDN      Asia  Indonesia  2020-03-04          2.0        0.0
# 30307      IDN      Asia  Indonesia  2020-03-05          2.0        0.0
# 30308      IDN      Asia  Indonesia  2020-03-06          4.0        2.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 30304                 NaN           NaN         NaN                  NaN  ...
# 30305                 NaN           NaN         NaN                  NaN  ...
# 30306                 NaN           NaN         NaN                  NaN  ...
# 30307                 NaN           NaN         NaN                  NaN  ...
# 30308                 NaN           NaN         NaN                  NaN  ...
#
# ...

# %%
usa_case.head()
# Out:
#       iso_code      continent       location        date  total_cases  \
# 68974      USA  North America  United States  2020-01-22          1.0
# 68975      USA  North America  United States  2020-01-23          1.0
# 68976      USA  North America  United States  2020-01-24          2.0
# 68977      USA  North America  United States  2020-01-25          2.0
# 68978      USA  North America  United States  2020-01-26          5.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 68974        NaN                 NaN           NaN         NaN
# 68975        0.0                 NaN           NaN         NaN
# 68976        1.0                 NaN           NaN         NaN
# 68977        0.0                 NaN           NaN         NaN
# 68978        3.0                 NaN           NaN         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 68974                  NaN  ...       54225.446              1.2
# ...

# %%
indonesia_case.tail()
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 30667      IDN      Asia  Indonesia  2021-02-28    1334634.0     5560.0
# 30668      IDN      Asia  Indonesia  2021-03-01    1341314.0     6680.0
# 30669      IDN      Asia  Indonesia  2021-03-02    1347026.0     5712.0
# 30670      IDN      Asia  Indonesia  2021-03-03    1353834.0     6808.0
# 30671      IDN      Asia  Indonesia  2021-03-04    1361098.0     7264.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 30667            7997.286       36166.0       185.0              239.571  ...
# 30668            7497.286       36325.0       159.0              233.429  ...
# 30669            6916.857       36518.0       193.0              214.857  ...
# 30670            6813.286       36721.0       203.0              209.571  ...
# 30671            6637.714       36897.0       176.0              197.000  ...
#
# ...

# %%
usa_case.tail()
# Out:
#       iso_code      continent       location        date  total_cases  \
# 69377      USA  North America  United States  2021-02-28   28578548.0
# 69378      USA  North America  United States  2021-03-01   28637313.0
# 69379      USA  North America  United States  2021-03-02   28694071.0
# 69380      USA  North America  United States  2021-03-03   28759980.0
# 69381      USA  North America  United States  2021-03-04   28827144.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 69377    51204.0           67314.000      512545.0      1037.0
# 69378    58765.0           67752.429      514061.0      1516.0
# 69379    56758.0           65630.714      515985.0      1924.0
# 69380    65909.0           64413.571      518453.0      2468.0
# 69381    67164.0           62950.286      520356.0      1903.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 69377             1943.857  ...       54225.446              1.2
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date", y="total_cases", data=indonesia_case)
plt.show()
