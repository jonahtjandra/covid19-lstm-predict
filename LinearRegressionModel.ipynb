# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
data = pd.read_csv("covid.csv")

# %%
data
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 72770      ZWE    Africa     Zimbabwe  2021-02-28      36089.0       31.0
# 72771      ZWE    Africa     Zimbabwe  2021-03-01      36115.0       26.0
# 72772      ZWE    Africa     Zimbabwe  2021-03-02      36148.0       33.0
# 72773      ZWE    Africa     Zimbabwe  2021-03-03      36179.0       31.0
# 72774      ZWE    Africa     Zimbabwe  2021-03-04      36223.0       44.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
data.dropna() #TODO: DOESN'T SEEM TO BE DROPPING NAN VALUES
data
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 72770      ZWE    Africa     Zimbabwe  2021-02-28      36089.0       31.0
# 72771      ZWE    Africa     Zimbabwe  2021-03-01      36115.0       26.0
# 72772      ZWE    Africa     Zimbabwe  2021-03-02      36148.0       33.0
# 72773      ZWE    Africa     Zimbabwe  2021-03-03      36179.0       31.0
# 72774      ZWE    Africa     Zimbabwe  2021-03-04      36223.0       44.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
reg = linear_model.LinearRegression()
reg.fit(data[['handwashing_facilities', 'hospital_beds_per_thousand', 'gdp_per_capita']], 'total_cases')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-1e11d97cc616> in <module>
#       1 reg = linear_model.LinearRegression()
# ----> 2 reg.fit(data[['handwashing_facilities', 'hospital_beds_per_thousand', 'gdp_per_capita']], 'total_cases')
#
# ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~/.local/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...
